# %%
import pandas as pd
import numpy as np

from IPython.display import display

# %%
df = pd.read_excel('2016OhioElectionExitPollTidy.xlsx')
display(df.head())

joined = pd.merge(df, df, on='Category')
joined = joined.loc[joined.Year_x < joined.Year_y]
joined = joined.loc[:, ['Category', 'Percentage_x', 'Percentage_y']]
joined.columns = ['Category', '2012', '2016']
display(joined)

joined.to_csv('ohio_exit_polls.csv')

display(pd.melt(joined, id_vars=['Category'], value_vars=['2012', '2016']))
# Out:
#    Year Category  Percentage
# 0  2012    Union        0.60
# 1  2012    18-24        0.62
# 2  2012    25-29        0.63
# 3  2012    30-39        0.55
# 4  2012    40-49        0.45
#           Category  2012  2016
# 1            Union  0.60  0.43
# 5            18-24  0.62  0.56
# 9            25-29  0.63  0.47
# 13           30-39  0.55  0.43
# 17           40-49  0.45  0.41
# 21           50-64  0.48  0.43
# 25             65+  0.44  0.43
# 29  Less than $50k  0.59  0.52
# 33    $50k or more  0.44  0.41
#           Category variable  value
# 0            Union     2012   0.60
# 1            18-24     2012   0.62
# 2            25-29     2012   0.63
# 3            30-39     2012   0.55
# 4            40-49     2012   0.45
# 5            50-64     2012   0.48
# 6              65+     2012   0.44
# 7   Less than $50k     2012   0.59
# 8     $50k or more     2012   0.44
# 9            Union     2016   0.43
# 10           18-24     2016   0.56
# 11           25-29     2016   0.47
# 12           30-39     2016   0.43
# 13           40-49     2016   0.41
# 14           50-64     2016   0.43
# 15             65+     2016   0.43
# 16  Less than $50k     2016   0.52
# 17    $50k or more     2016   0.41

# %%
df = pd.read_csv('data/exit_polls.csv')

joined = pd.merge(df, df, on=['state', 'pollname', 'answer'])
joined = joined.loc[joined.year_x < joined.year_y]
joined = joined.loc[:, ['state', 'pollname', 'question_y', 'answer', 'democrat_x', 'republican_x', 'democrat_y', 'republican_y']]
joined.columns = ['state', 'pollname', 'question', 'answer', 'democrat_2012', 'republican_2012', 'democrat_2016', 'republican_2016']

melted = pd.melt(joined, id_vars=['state', 'pollname', 'question', 'answer'], value_vars=['democrat_2012', 'republican_2012', 'democrat_2016', 'republican_2016'])
melted.columns = ['state', 'pollname', 'question', 'answer', 'year', 'value']
melted.year = melted.year.str.replace("[democrat_|republican_]", '')

melted = melted.fillna(0)

#display(df.head())
#display(df.dtypes)
#display(joined)
display(melted)

melted.to_csv('exit_polls_tidy.csv')
# Out:
#      state   pollname                                    question  \
# 0       AZ        SEX                                      Gender
# 1       AZ        SEX                                      Gender
# 2       AZ        AGE                                         Age
# 3       AZ        AGE                                         Age
# 4       AZ        AGE                                         Age
# 5       AZ        AGE                                         Age
# 6       AZ      AGE65                                         Age
# 7       AZ      AGE65                                         Age
# 8       AZ      AGE65                                         Age
# 9       AZ      AGE65                                         Age
# 10      AZ      AGE65                                         Age
# 11      AZ      AGE65                                         Age
# 12      AZ       RACE                                        Race
# 13      AZ       RACE                                        Race
# 14      AZ       RACE                                        Race
# 15      AZ       RACE                                        Race
# 16      AZ  SEXBYRACE                             Race and gender
# 17      AZ  SEXBYRACE                             Race and gender
# 18      AZ  SEXBYRACE                             Race and gender
# 19      AZ  SEXBYRACE                             Race and gender
# 20      AZ  SEXBYRACE                             Race and gender
# 21      AZ  SEXBYRACE                             Race and gender
# 22      AZ  SEXBYRACE                             Race and gender
# 23      AZ      PHIL3                                    Ideology
# 24      AZ      PHIL3                                    Ideology
# 25      AZ      PHIL3                                    Ideology
# 26      AZ   EDUCCOLL                 Are you a college graduate?
# 27      AZ   EDUCCOLL                 Are you a college graduate?
# 28      AZ    INCOME3                                      Income
# 29      AZ    INCOME3                                      Income
# ...    ...        ...                                         ...
# 3906    WI       RACE                                        Race
# 3907    WI  SEXBYRACE                             Race and gender
# 3908    WI  SEXBYRACE                             Race and gender
# 3909    WI  SEXBYRACE                             Race and gender
# 3910    WI  SEXBYRACE                             Race and gender
# 3911    WI  SEXBYRACE                             Race and gender
# 3912    WI  SEXBYRACE                             Race and gender
# 3913    WI  SEXBYRACE                             Race and gender
# 3914    WI      PHIL3                                    Ideology
# 3915    WI      PHIL3                                    Ideology
# 3916    WI      PHIL3                                    Ideology
# 3917    WI   EDUCCOLL                 Are you a college graduate?
# 3918    WI   EDUCCOLL                 Are you a college graduate?
# 3919    WI    INCOME3                                      Income
# 3920    WI    INCOME3                                      Income
# 3921    WI    INCOME3                                      Income
# 3922    WI     INC50K                                      Income
# 3923    WI     INC50K                                      Income
# 3924    WI   WHTEVANG  White born-again or evangelical Christian?
# 3925    WI   WHTEVANG  White born-again or evangelical Christian?
# 3926    WI        NEC               Condition of national economy
# 3927    WI        NEC               Condition of national economy
# 3928    WI        NEC               Condition of national economy
# 3929    WI    MARRIED                              Marital status
# 3930    WI    MARRIED                              Marital status
# 3931    WI  UNIONHH12                            Union household?
# 3932    WI  UNIONHH12                            Union household?
# 3933    WI   FAVRYAN2                        Opinion of Paul Ryan
# 3934    WI   FAVRYAN2                        Opinion of Paul Ryan
# 3935    WI     GEOCOD                                      Region
#
#                 answer  year  value
# 0                 Male  2012   40.0
# 1               Female  2012   46.0
# 2                18-29  2012   63.0
# 3                30-44  2012   37.0
# 4                45-64  2012   38.0
# 5         65 and older  2012   29.0
# 6                18-24  2012   66.0
# 7                25-29  2012   59.0
# 8                30-39  2012   37.0
# 9                40-49  2012   40.0
# 10               50-64  2012   36.0
# 11        65 and older  2012   29.0
# 12               White  2012   32.0
# 13               Black  2012    0.0
# 14              Latino  2012   74.0
# 15               Asian  2012    0.0
# 16           White men  2012   30.0
# 17         White women  2012   35.0
# 18           Black men  2012    0.0
# 19         Black women  2012    0.0
# 20          Latino men  2012   71.0
# 21        Latino women  2012   77.0
# 22              Others  2012    0.0
# 23             Liberal  2012   86.0
# 24            Moderate  2012   51.0
# 25        Conservative  2012   12.0
# 26                 Yes  2012   42.0
# 27                  No  2012   44.0
# 28          Under $50K  2012   47.0
# 29          $50K-$100K  2012   41.0
# ...                ...   ...    ...
# 3906             Asian  2016    0.0
# 3907         White men  2016   59.0
# 3908       White women  2016   47.0
# 3909         Black men  2016    8.0
# 3910       Black women  2016    3.0
# 3911        Latino men  2016    0.0
# 3912      Latino women  2016    0.0
# 3913            Others  2016    0.0
# 3914           Liberal  2016   10.0
# 3915          Moderate  2016   42.0
# 3916      Conservative  2016   85.0
# 3917               Yes  2016   39.0
# 3918                No  2016   56.0
# 3919        Under $50K  2016   45.0
# 3920        $50K-$100K  2016   52.0
# 3921     $100K or more  2016   46.0
# 3922        Under $50K  2016   45.0
# 3923      $50K or more  2016   50.0
# 3924               Yes  2016   73.0
# 3925                No  2016   38.0
# 3926         Excellent  2016    0.0
# 3927              Good  2016   21.0
# 3928              Poor  2016   78.0
# 3929           Married  2016   55.0
# 3930         Unmarried  2016   43.0
# 3931             Union  2016   43.0
# 3932         Not Union  2016   52.0
# 3933         Favorable  2016   63.0
# 3934       Unfavorable  2016   30.0
# 3935  Milwaukee County  2016   27.0
#
# [3936 rows x 6 columns]
