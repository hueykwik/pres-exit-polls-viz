# %%
import pandas as pd
import numpy as np

from IPython.display import display

# %%
df = pd.read_excel('2016OhioElectionExitPollTidy.xlsx')
display(df.head())

joined = pd.merge(df, df, on='Category')
joined = joined.loc[joined.Year_x < joined.Year_y]
joined = joined.loc[:, ['Category', 'Percentage_x', 'Percentage_y']]
joined.columns = ['Category', '2012', '2016']
display(joined)

joined.to_csv('ohio_exit_polls.csv')

display(pd.melt(joined, id_vars=['Category'], value_vars=['2012', '2016']))
# Out:
#    Year Category  Percentage
# 0  2012    Union        0.60
# 1  2012    18-24        0.62
# 2  2012    25-29        0.63
# 3  2012    30-39        0.55
# 4  2012    40-49        0.45
#           Category  2012  2016
# 1            Union  0.60  0.43
# 5            18-24  0.62  0.56
# 9            25-29  0.63  0.47
# 13           30-39  0.55  0.43
# 17           40-49  0.45  0.41
# 21           50-64  0.48  0.43
# 25             65+  0.44  0.43
# 29  Less than $50k  0.59  0.52
# 33    $50k or more  0.44  0.41
#           Category variable  value
# 0            Union     2012   0.60
# 1            18-24     2012   0.62
# 2            25-29     2012   0.63
# 3            30-39     2012   0.55
# 4            40-49     2012   0.45
# 5            50-64     2012   0.48
# 6              65+     2012   0.44
# 7   Less than $50k     2012   0.59
# 8     $50k or more     2012   0.44
# 9            Union     2016   0.43
# 10           18-24     2016   0.56
# 11           25-29     2016   0.47
# 12           30-39     2016   0.43
# 13           40-49     2016   0.41
# 14           50-64     2016   0.43
# 15             65+     2016   0.43
# 16  Less than $50k     2016   0.52
# 17    $50k or more     2016   0.41

# %%
df = pd.read_csv('data/exit_polls.csv')

joined = pd.merge(df, df, on=['state', 'pollname', 'answer'])
joined = joined.loc[joined.year_x < joined.year_y]
joined = joined.loc[:, ['state', 'pollname', 'question_y', 'answer', 'democrat_x', 'republican_x', 'democrat_y', 'republican_y']]
joined.columns = ['state', 'pollname', 'question', 'answer', 'democrat_2012', 'republican_2012', 'democrat_2016', 'republican_2016']
joined = joined.dropna()


df2012 = joined[['state', 'pollname', 'question', 'answer', 'democrat_2012', 'republican_2012']].copy()
df2016 = joined[['state', 'pollname', 'question', 'answer', 'democrat_2016', 'republican_2016']].copy()

cols = ['state', 'pollname', 'question', 'answer', 'democrat', 'republican']

df2012.columns = cols
df2016.columns = cols

df2012['year'] = 2012
df2016['year'] = 2016

melted = df2012.append(df2016)
melted = melted.fillna(0)
display(melted)

# Excluding these polltypes for two reasons:
# 1. They overlap with an existing pollname (e.g. AGE vs AGE 65)
# 2. They have Yes or No answers, so it's ambigious when it shows up in the chart. I can fix this later if it's really interesting.
melted = melted.loc[~melted['pollname'].isin(['AGE65', 'BREAK12B', 'CHILD12', 'EDUCOLL', 'FAVRYAN2', 'GEOCOD', 'INC50K', 'NEC', 'OBAMA2', 'SEXBYRACE', 'UNIONHH12', 'WHITEVANG'])]

melted.to_csv('exit_polls_tidy.csv', index=False)
# Out:
#      state   pollname                                    question  \
# 101     AZ        SEX                                      Gender
# 105     AZ        SEX                                      Gender
# 109     AZ        AGE                                         Age
# 113     AZ        AGE                                         Age
# 117     AZ        AGE                                         Age
# 121     AZ        AGE                                         Age
# 133     AZ      AGE65                                         Age
# 137     AZ      AGE65                                         Age
# 141     AZ      AGE65                                         Age
# 145     AZ      AGE65                                         Age
# 149     AZ       RACE                                        Race
# 157     AZ       RACE                                        Race
# 166     AZ  SEXBYRACE                             Race and gender
# 170     AZ  SEXBYRACE                             Race and gender
# 182     AZ  SEXBYRACE                             Race and gender
# 186     AZ  SEXBYRACE                             Race and gender
# 194     AZ      PHIL3                                    Ideology
# 198     AZ      PHIL3                                    Ideology
# 202     AZ      PHIL3                                    Ideology
# 214     AZ   EDUCCOLL                 Are you a college graduate?
# 218     AZ   EDUCCOLL                 Are you a college graduate?
# 224     AZ    INCOME3                                      Income
# 228     AZ    INCOME3                                      Income
# 232     AZ    INCOME3                                      Income
# 236     AZ     INC50K                                      Income
# 240     AZ     INC50K                                      Income
# 323     AZ        NEC               Condition of national economy
# 357     AZ     OBAMA2        Opinion of Barack Obama as president
# 361     AZ     OBAMA2        Opinion of Barack Obama as president
# 431     AZ     GEOCOD                                      Region
# ...    ...        ...                                         ...
# 7397    WI      AGE65                                         Age
# 7401    WI      AGE65                                         Age
# 7405    WI       RACE                                        Race
# 7409    WI       RACE                                        Race
# 7413    WI       RACE                                        Race
# 7422    WI  SEXBYRACE                             Race and gender
# 7426    WI  SEXBYRACE                             Race and gender
# 7430    WI  SEXBYRACE                             Race and gender
# 7434    WI  SEXBYRACE                             Race and gender
# 7450    WI      PHIL3                                    Ideology
# 7454    WI      PHIL3                                    Ideology
# 7458    WI      PHIL3                                    Ideology
# 7470    WI   EDUCCOLL                 Are you a college graduate?
# 7474    WI   EDUCCOLL                 Are you a college graduate?
# 7480    WI    INCOME3                                      Income
# 7484    WI    INCOME3                                      Income
# 7488    WI    INCOME3                                      Income
# 7492    WI     INC50K                                      Income
# 7496    WI     INC50K                                      Income
# 7513    WI   WHTEVANG  White born-again or evangelical Christian?
# 7517    WI   WHTEVANG  White born-again or evangelical Christian?
# 7562    WI        NEC               Condition of national economy
# 7567    WI        NEC               Condition of national economy
# 7613    WI    MARRIED                              Marital status
# 7617    WI    MARRIED                              Marital status
# 7633    WI  UNIONHH12                            Union household?
# 7637    WI  UNIONHH12                            Union household?
# 7645    WI   FAVRYAN2                        Opinion of Paul Ryan
# 7649    WI   FAVRYAN2                        Opinion of Paul Ryan
# 7660    WI     GEOCOD                                      Region
#
#                 answer  democrat  republican  year
# 101               Male      40.0        57.0  2012
# 105             Female      46.0        53.0  2012
# 109              18-29      63.0        36.0  2012
# 113              30-44      37.0        59.0  2012
# 117              45-64      38.0        61.0  2012
# 121       65 and older      29.0        71.0  2012
# 133              30-39      37.0        58.0  2012
# 137              40-49      40.0        58.0  2012
# 141              50-64      36.0        64.0  2012
# 145       65 and older      29.0        71.0  2012
# 149              White      32.0        66.0  2012
# 157             Latino      74.0        25.0  2012
# 166          White men      30.0        67.0  2012
# 170        White women      35.0        65.0  2012
# 182         Latino men      71.0        27.0  2012
# 186       Latino women      77.0        22.0  2012
# 194            Liberal      86.0        12.0  2012
# 198           Moderate      51.0        46.0  2012
# 202       Conservative      12.0        87.0  2012
# 214                Yes      42.0        56.0  2012
# 218                 No      44.0        55.0  2012
# 224         Under $50K      47.0        51.0  2012
# 228         $50K-$100K      41.0        57.0  2012
# 232      $100K or more      43.0        56.0  2012
# 236         Under $50K      47.0        51.0  2012
# 240       $50K or more      42.0        56.0  2012
# 323               Poor      17.0        77.0  2012
# 357            Approve      91.0         7.0  2012
# 361         Disapprove       3.0        94.0  2012
# 431        Pima County      48.0        50.0  2012
# ...                ...       ...         ...   ...
# 7397             50-64      41.0        56.0  2016
# 7401      65 and older      48.0        49.0  2016
# 7405             White      42.0        53.0  2016
# 7409             Black      92.0         6.0  2016
# 7413            Latino      63.0        34.0  2016
# 7422         White men      35.0        59.0  2016
# 7426       White women      49.0        47.0  2016
# 7430         Black men      90.0         8.0  2016
# 7434       Black women      94.0         3.0  2016
# 7450           Liberal      86.0        10.0  2016
# 7454          Moderate      52.0        42.0  2016
# 7458      Conservative      11.0        85.0  2016
# 7470               Yes      55.0        39.0  2016
# 7474                No      40.0        56.0  2016
# 7480        Under $50K      49.0        45.0  2016
# 7484        $50K-$100K      46.0        52.0  2016
# 7488     $100K or more      48.0        46.0  2016
# 7492        Under $50K      49.0        45.0  2016
# 7496      $50K or more      47.0        50.0  2016
# 7513               Yes      23.0        73.0  2016
# 7517                No      57.0        38.0  2016
# 7562              Good      77.0        21.0  2016
# 7567              Poor      16.0        78.0  2016
# 7613           Married      40.0        55.0  2016
# 7617         Unmarried      51.0        43.0  2016
# 7633             Union      53.0        43.0  2016
# 7637         Not Union      44.0        52.0  2016
# 7645         Favorable      32.0        63.0  2016
# 7649       Unfavorable      66.0        30.0  2016
# 7660  Milwaukee County      67.0        27.0  2016
#
# [1608 rows x 7 columns]

# %%
melted.groupby('pollname').first()
# Out:
#           state                                    question       answer  \
# pollname
# AGE          AZ                                         Age        18-29
# AGE65        AZ                                         Age        18-24
# BREAK12B     CA         Were debates a factor in your vote?          Yes
# CHILD12      NC                                     Parent?          Yes
# EDUCCOLL     AZ                 Are you a college graduate?          Yes
# FAVRYAN2     WI                        Opinion of Paul Ryan    Favorable
# GEOCOD       AZ                                      Region  Pima County
# INC50K       AZ                                      Income   Under $50K
# INCOME3      AZ                                      Income   Under $50K
# MARRIED      CA                              Marital status      Married
# NEC          AZ               Condition of national economy    Excellent
# OBAMA2       AZ        Opinion of Barack Obama as president      Approve
# PARENTS      NC                           Parents by gender      Fathers
# PHIL3        AZ                                    Ideology      Liberal
# RACE         AZ                                        Race        White
# REL5         CA                                    Religion   Protestant
# SEX          AZ                                      Gender         Male
# SEXBYRACE    AZ                             Race and gender    White men
# UNIONHH12    CA                            Union household?        Union
# WHTEVANG     CA  White born-again or evangelical Christian?          Yes
#
#            democrat  republican  year
# pollname
# AGE            63.0        36.0  2012
# AGE65          66.0        32.0  2012
# BREAK12B       70.0        29.0  2012
# CHILD12        52.0        48.0  2012
# EDUCCOLL       42.0        56.0  2012
# FAVRYAN2       12.0        87.0  2012
# GEOCOD         48.0        50.0  2012
# INC50K         47.0        51.0  2012
# INCOME3        47.0        51.0  2012
# MARRIED        51.0        48.0  2012
# NEC             0.0         0.0  2012
# OBAMA2         91.0         7.0  2012
# PARENTS        50.0        50.0  2012
# PHIL3          86.0        12.0  2012
# RACE           32.0        66.0  2012
# REL5           46.0        52.0  2012
# SEX            40.0        57.0  2012
# SEXBYRACE      30.0        67.0  2012
# UNIONHH12      67.0        31.0  2012
# WHTEVANG        0.0         0.0  2012

# %%
# Out:
#      state  pollname                                    question  \
# 101     AZ       SEX                                      Gender
# 105     AZ       SEX                                      Gender
# 109     AZ       AGE                                         Age
# 113     AZ       AGE                                         Age
# 117     AZ       AGE                                         Age
# 121     AZ       AGE                                         Age
# 149     AZ      RACE                                        Race
# 153     AZ      RACE                                        Race
# 157     AZ      RACE                                        Race
# 161     AZ      RACE                                        Race
# 194     AZ     PHIL3                                    Ideology
# 198     AZ     PHIL3                                    Ideology
# 202     AZ     PHIL3                                    Ideology
# 214     AZ  EDUCCOLL                 Are you a college graduate?
# 218     AZ  EDUCCOLL                 Are you a college graduate?
# 224     AZ   INCOME3                                      Income
# 228     AZ   INCOME3                                      Income
# 232     AZ   INCOME3                                      Income
# 439     CA       SEX                                      Gender
# 443     CA       SEX                                      Gender
# 447     CA       AGE                                         Age
# 451     CA       AGE                                         Age
# 455     CA       AGE                                         Age
# 459     CA       AGE                                         Age
# 487     CA      RACE                                        Race
# 491     CA      RACE                                        Race
# 495     CA      RACE                                        Race
# 499     CA      RACE                                        Race
# 532     CA     PHIL3                                    Ideology
# 536     CA     PHIL3                                    Ideology
# ...    ...       ...                                         ...
# 7206    WA     PHIL3                                    Ideology
# 7210    WA     PHIL3                                    Ideology
# 7214    WA     PHIL3                                    Ideology
# 7226    WA  EDUCCOLL                 Are you a college graduate?
# 7230    WA  EDUCCOLL                 Are you a college graduate?
# 7236    WA   INCOME3                                      Income
# 7240    WA   INCOME3                                      Income
# 7244    WA   INCOME3                                      Income
# 7357    WI       SEX                                      Gender
# 7361    WI       SEX                                      Gender
# 7365    WI       AGE                                         Age
# 7369    WI       AGE                                         Age
# 7373    WI       AGE                                         Age
# 7377    WI       AGE                                         Age
# 7405    WI      RACE                                        Race
# 7409    WI      RACE                                        Race
# 7413    WI      RACE                                        Race
# 7417    WI      RACE                                        Race
# 7450    WI     PHIL3                                    Ideology
# 7454    WI     PHIL3                                    Ideology
